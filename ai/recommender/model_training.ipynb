# %% [markdown]
# # Entraînement du modèle de recommandation SmartBooker
#
# Ce notebook contient le code pour entraîner le modèle de recommandation personnalisé.

# %%
import pandas as pd
import numpy as np
from recommender import Recommender

# Charger les données
# TODO: Charger les données d'entraînement

# Initialiser le recommandeur
recommender = Recommender()

# Entraîner le modèle
# recommender.train(services_data, user_history)

print("Modèle entraîné avec succès!")
